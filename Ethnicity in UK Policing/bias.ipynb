# %% [markdown]
# <a href="https://colab.research.google.com/github/ah20776/CE888---Assignment/blob/main/Ethnicity%20in%20UK%20Policing/bias.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import warnings
warnings.filterwarnings("ignore")

# %%
#connecting google drive for importing datasets

from google.colab import drive
drive.mount("/content/gdrive")
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
#Data import

essex18_1 = pd.read_csv('/content/gdrive/My Drive/CE888 - Dataset/Essex 2018-20/2018-01-essex-stop-and-search.csv')
essex18_1.head()
# Out:
#              Type  ... Removal of more than just outer clothing
# 0   Person search  ...                                    False
# 1   Person search  ...                                    False
# 2   Person search  ...                                    False
# 3   Person search  ...                                    False
# 4  Vehicle search  ...                                      NaN
#
# [5 rows x 15 columns]

# %%
print (essex18_1.shape)
# Out:
# (380, 15)

# %%
essex18_1["Date"] = "2018-01"
essex18_1.head()
# Out:
#              Type  ... Removal of more than just outer clothing
# 0   Person search  ...                                    False
# 1   Person search  ...                                    False
# 2   Person search  ...                                    False
# 3   Person search  ...                                    False
# 4  Vehicle search  ...                                      NaN
#
# [5 rows x 15 columns]

# %%
essex18_2 = pd.read_csv('/content/gdrive/My Drive/CE888 - Dataset/Essex 2018-20/2018-02-essex-stop-and-search.csv')
essex18_2["Date"] = "2018-02"
essex18_3 = pd.read_csv('/content/gdrive/My Drive/CE888 - Dataset/Essex 2018-20/2018-03-essex-stop-and-search.csv')
essex18_3["Date"] = "2018-03"
essex18_4 = pd.read_csv('/content/gdrive/My Drive/CE888 - Dataset/Essex 2018-20/2018-04-essex-stop-and-search.csv')
essex18_4["Date"] = "2018-04"
essex18_5 = pd.read_csv('/content/gdrive/My Drive/CE888 - Dataset/Essex 2018-20/2018-05-essex-stop-and-search.csv')
essex18_5["Date"] = "2018-05"
essex18_6 = pd.read_csv('/content/gdrive/My Drive/CE888 - Dataset/Essex 2018-20/2018-06-essex-stop-and-search.csv')
essex18_6["Date"] = "2018-06"
essex18_7 = pd.read_csv('/content/gdrive/My Drive/CE888 - Dataset/Essex 2018-20/2018-07-essex-stop-and-search.csv')
essex18_7["Date"] = "2018-07"
essex18_8 = pd.read_csv('/content/gdrive/My Drive/CE888 - Dataset/Essex 2018-20/2018-08-essex-stop-and-search.csv')
essex18_8["Date"] = "2018-08"
essex18_9 = pd.read_csv('/content/gdrive/My Drive/CE888 - Dataset/Essex 2018-20/2018-09-essex-stop-and-search.csv')
essex18_9["Date"] = "2018-09"
essex18_10 = pd.read_csv('/content/gdrive/My Drive/CE888 - Dataset/Essex 2018-20/2018-10-essex-stop-and-search.csv')
essex18_10["Date"] = "2018-10"
essex18_11 = pd.read_csv('/content/gdrive/My Drive/CE888 - Dataset/Essex 2018-20/2018-11-essex-stop-and-search.csv')
essex18_11["Date"] = "2018-11"
essex18_12 = pd.read_csv('/content/gdrive/My Drive/CE888 - Dataset/Essex 2018-20/2018-12-essex-stop-and-search.csv')
essex18_12["Date"] = "2018-12"

# %%
#Essex in 2018

essex18 = pd.concat([essex18_1,essex18_2,essex18_3,essex18_4,essex18_5,essex18_6,essex18_7,essex18_8,essex18_9,essex18_10,essex18_11,essex18_12])
essex18.head()
# Out:
#              Type  ... Removal of more than just outer clothing
# 0   Person search  ...                                    False
# 1   Person search  ...                                    False
# 2   Person search  ...                                    False
# 3   Person search  ...                                    False
# 4  Vehicle search  ...                                      NaN
#
# [5 rows x 15 columns]

# %%
print (essex18.shape)
# Out:
# (5942, 15)

# %%
essex19_1 = pd.read_csv('/content/gdrive/My Drive/CE888 - Dataset/Essex 2018-20/2019-01-essex-stop-and-search.csv')
essex19_1["Date"] = "2019-01"
essex19_2 = pd.read_csv('/content/gdrive/My Drive/CE888 - Dataset/Essex 2018-20/2019-02-essex-stop-and-search.csv')
essex19_2["Date"] = "2019-02"
essex19_3 = pd.read_csv('/content/gdrive/My Drive/CE888 - Dataset/Essex 2018-20/2019-03-essex-stop-and-search.csv')
essex18_3["Date"] = "2019-03"
essex19_4 = pd.read_csv('/content/gdrive/My Drive/CE888 - Dataset/Essex 2018-20/2019-04-essex-stop-and-search.csv')
essex19_4["Date"] = "2019-04"
essex19_5 = pd.read_csv('/content/gdrive/My Drive/CE888 - Dataset/Essex 2018-20/2019-05-essex-stop-and-search.csv')
essex19_5["Date"] = "2019-05"
essex19_6 = pd.read_csv('/content/gdrive/My Drive/CE888 - Dataset/Essex 2018-20/2019-06-essex-stop-and-search.csv')
essex19_6["Date"] = "2019-06"
essex19_7 = pd.read_csv('/content/gdrive/My Drive/CE888 - Dataset/Essex 2018-20/2019-07-essex-stop-and-search.csv')
essex19_7["Date"] = "2019-07"
essex19_8 = pd.read_csv('/content/gdrive/My Drive/CE888 - Dataset/Essex 2018-20/2019-08-essex-stop-and-search.csv')
essex19_8["Date"] = "2019-08"
essex19_9 = pd.read_csv('/content/gdrive/My Drive/CE888 - Dataset/Essex 2018-20/2019-09-essex-stop-and-search.csv')
essex19_9["Date"] = "2019-09"
essex19_10 = pd.read_csv('/content/gdrive/My Drive/CE888 - Dataset/Essex 2018-20/2019-10-essex-stop-and-search.csv')
essex19_10["Date"] = "2019-10"
essex19_11 = pd.read_csv('/content/gdrive/My Drive/CE888 - Dataset/Essex 2018-20/2019-11-essex-stop-and-search.csv')
essex19_11["Date"] = "2019-11"
essex19_12 = pd.read_csv('/content/gdrive/My Drive/CE888 - Dataset/Essex 2018-20/2019-12-essex-stop-and-search.csv')
essex19_12["Date"] = "2019-12"
essex20_1 = pd.read_csv('/content/gdrive/My Drive/CE888 - Dataset/Essex 2018-20/2019-01-essex-stop-and-search.csv')
essex20_1["Date"] = "2020-01"
essex20_2 = pd.read_csv('/content/gdrive/My Drive/CE888 - Dataset/Essex 2018-20/2019-02-essex-stop-and-search.csv')
essex20_2["Date"] = "2020-02"
essex20_3 = pd.read_csv('/content/gdrive/My Drive/CE888 - Dataset/Essex 2018-20/2019-03-essex-stop-and-search.csv')
essex20_3["Date"] = "2020-03"
essex20_4 = pd.read_csv('/content/gdrive/My Drive/CE888 - Dataset/Essex 2018-20/2019-04-essex-stop-and-search.csv')
essex20_4["Date"] = "2020-04"
essex20_5 = pd.read_csv('/content/gdrive/My Drive/CE888 - Dataset/Essex 2018-20/2019-05-essex-stop-and-search.csv')
essex20_5["Date"] = "2020-05"
essex20_6 = pd.read_csv('/content/gdrive/My Drive/CE888 - Dataset/Essex 2018-20/2019-06-essex-stop-and-search.csv')
essex20_6["Date"] = "2020-06"
essex20_7 = pd.read_csv('/content/gdrive/My Drive/CE888 - Dataset/Essex 2018-20/2019-07-essex-stop-and-search.csv')
essex20_7["Date"] = "2020-07"
essex20_8 = pd.read_csv('/content/gdrive/My Drive/CE888 - Dataset/Essex 2018-20/2019-08-essex-stop-and-search.csv')
essex20_8["Date"] = "2020-08"
essex20_9 = pd.read_csv('/content/gdrive/My Drive/CE888 - Dataset/Essex 2018-20/2019-09-essex-stop-and-search.csv')
essex20_9["Date"] = "2020-09"
essex20_10 = pd.read_csv('/content/gdrive/My Drive/CE888 - Dataset/Essex 2018-20/2019-10-essex-stop-and-search.csv')
essex20_10["Date"] = "2020-10"
essex20_11 = pd.read_csv('/content/gdrive/My Drive/CE888 - Dataset/Essex 2018-20/2019-11-essex-stop-and-search.csv')
essex20_11["Date"] = "2020-11"
essex20_12 = pd.read_csv('/content/gdrive/My Drive/CE888 - Dataset/Essex 2018-20/2019-12-essex-stop-and-search.csv')
essex20_12["Date"] = "2020-12"
essex19 = pd.concat([essex19_1,essex19_2,essex19_3,essex19_4,essex19_5,essex19_6,essex19_7,essex19_8,essex19_9,essex19_10,essex19_11,essex19_12])
essex20 = pd.concat([essex20_1,essex20_2,essex20_3,essex20_4,essex20_5,essex20_6,essex20_7,essex20_8,essex20_9,essex20_10,essex20_11,essex20_12])
essex = pd.concat([essex18,essex19,essex20])
essex.head()
# Out:
#              Type  ... Removal of more than just outer clothing
# 0   Person search  ...                                    False
# 1   Person search  ...                                    False
# 2   Person search  ...                                    False
# 3   Person search  ...                                    False
# 4  Vehicle search  ...                                      NaN
#
# [5 rows x 15 columns]

# %%
print (essex.shape)
# Out:
# (40234, 15)

# %%
#adding column for city
essex["City"] = "Essex"
essex.head()

#ESSEX DATA
# Out:
#              Type     Date  ...  Removal of more than just outer clothing   City
# 0   Person search  2018-01  ...                                     False  Essex
# 1   Person search  2018-01  ...                                     False  Essex
# 2   Person search  2018-01  ...                                     False  Essex
# 3   Person search  2018-01  ...                                     False  Essex
# 4  Vehicle search  2018-01  ...                                       NaN  Essex
#
# [5 rows x 16 columns]

# %%
kent18_1 = pd.read_csv('/content/gdrive/My Drive/CE888 - Dataset/Kent 2018-20/2018-01-kent-stop-and-search.csv')
kent18_1["Date"] = "2018-01"
kent18_2 = pd.read_csv('/content/gdrive/My Drive/CE888 - Dataset/Kent 2018-20/2018-02-kent-stop-and-search.csv')
kent18_2["Date"] = "2018-02"
kent18_3 = pd.read_csv('/content/gdrive/My Drive/CE888 - Dataset/Kent 2018-20/2018-03-kent-stop-and-search.csv')
kent18_3["Date"] = "2018-03"
kent18_4 = pd.read_csv('/content/gdrive/My Drive/CE888 - Dataset/Kent 2018-20/2018-04-kent-stop-and-search.csv')
kent18_4["Date"] = "2018-04"
kent18_5 = pd.read_csv('/content/gdrive/My Drive/CE888 - Dataset/Kent 2018-20/2018-05-kent-stop-and-search.csv')
kent18_5["Date"] = "2018-05"
kent18_6 = pd.read_csv('/content/gdrive/My Drive/CE888 - Dataset/Kent 2018-20/2018-06-kent-stop-and-search.csv')
kent18_6["Date"] = "2018-06"
kent18_7 = pd.read_csv('/content/gdrive/My Drive/CE888 - Dataset/Kent 2018-20/2018-07-kent-stop-and-search.csv')
kent18_7["Date"] = "2018-07"
kent18_8 = pd.read_csv('/content/gdrive/My Drive/CE888 - Dataset/Kent 2018-20/2018-08-kent-stop-and-search.csv')
kent18_8["Date"] = "2018-08"
kent18_9 = pd.read_csv('/content/gdrive/My Drive/CE888 - Dataset/Kent 2018-20/2018-09-kent-stop-and-search.csv')
kent18_9["Date"] = "2018-09"
kent18_10 = pd.read_csv('/content/gdrive/My Drive/CE888 - Dataset/Kent 2018-20/2018-10-kent-stop-and-search.csv')
kent18_10["Date"] = "2018-10"
kent18_11 = pd.read_csv('/content/gdrive/My Drive/CE888 - Dataset/Kent 2018-20/2018-11-kent-stop-and-search.csv')
kent18_11["Date"] = "2018-11"
kent18_12 = pd.read_csv('/content/gdrive/My Drive/CE888 - Dataset/Kent 2018-20/2018-12-kent-stop-and-search.csv')
kent18_12["Date"] = "2018-12"
kent19_1 = pd.read_csv('/content/gdrive/My Drive/CE888 - Dataset/Kent 2018-20/2019-01-kent-stop-and-search.csv')
kent19_1["Date"] = "2019-01"
kent19_2 = pd.read_csv('/content/gdrive/My Drive/CE888 - Dataset/Kent 2018-20/2019-02-kent-stop-and-search.csv')
kent19_2["Date"] = "2019-02"
kent19_3 = pd.read_csv('/content/gdrive/My Drive/CE888 - Dataset/Kent 2018-20/2019-03-kent-stop-and-search.csv')
kent19_3["Date"] = "2019-03"
kent19_4 = pd.read_csv('/content/gdrive/My Drive/CE888 - Dataset/Kent 2018-20/2019-04-kent-stop-and-search.csv')
kent19_4["Date"] = "2019-04"
kent19_5 = pd.read_csv('/content/gdrive/My Drive/CE888 - Dataset/Kent 2018-20/2019-05-kent-stop-and-search.csv')
kent19_5["Date"] = "2019-05"
kent19_6 = pd.read_csv('/content/gdrive/My Drive/CE888 - Dataset/Kent 2018-20/2019-06-kent-stop-and-search.csv')
kent19_6["Date"] = "2019-06"
kent19_7 = pd.read_csv('/content/gdrive/My Drive/CE888 - Dataset/Kent 2018-20/2019-07-kent-stop-and-search.csv')
kent19_7["Date"] = "2019-07"
kent19_8 = pd.read_csv('/content/gdrive/My Drive/CE888 - Dataset/Kent 2018-20/2019-08-kent-stop-and-search.csv')
kent19_8["Date"] = "2019-08"
kent19_9 = pd.read_csv('/content/gdrive/My Drive/CE888 - Dataset/Kent 2018-20/2019-09-kent-stop-and-search.csv')
kent19_9["Date"] = "2019-09"
kent19_10 = pd.read_csv('/content/gdrive/My Drive/CE888 - Dataset/Kent 2018-20/2019-10-kent-stop-and-search.csv')
kent19_10["Date"] = "2019-10"
kent19_11 = pd.read_csv('/content/gdrive/My Drive/CE888 - Dataset/Kent 2018-20/2019-11-kent-stop-and-search.csv')
kent19_11["Date"] = "2019-11"
kent19_12 = pd.read_csv('/content/gdrive/My Drive/CE888 - Dataset/Kent 2018-20/2019-12-kent-stop-and-search.csv')
kent19_12["Date"] = "2019-12"
kent20_1 = pd.read_csv('/content/gdrive/My Drive/CE888 - Dataset/Kent 2018-20/2020-01-kent-stop-and-search.csv')
kent20_1["Date"] = "2020-01"
kent20_2 = pd.read_csv('/content/gdrive/My Drive/CE888 - Dataset/Kent 2018-20/2020-02-kent-stop-and-search.csv')
kent20_2["Date"] = "2020-02"
kent20_3 = pd.read_csv('/content/gdrive/My Drive/CE888 - Dataset/Kent 2018-20/2020-03-kent-stop-and-search.csv')
kent20_3["Date"] = "2020-03"
kent20_4 = pd.read_csv('/content/gdrive/My Drive/CE888 - Dataset/Kent 2018-20/2020-04-kent-stop-and-search.csv')
kent20_4["Date"] = "2020-04"
kent20_5 = pd.read_csv('/content/gdrive/My Drive/CE888 - Dataset/Kent 2018-20/2020-05-kent-stop-and-search.csv')
kent20_5["Date"] = "2020-05"
kent20_6 = pd.read_csv('/content/gdrive/My Drive/CE888 - Dataset/Kent 2018-20/2020-06-kent-stop-and-search.csv')
kent20_6["Date"] = "2020-06"
kent20_7 = pd.read_csv('/content/gdrive/My Drive/CE888 - Dataset/Kent 2018-20/2020-07-kent-stop-and-search.csv')
kent20_7["Date"] = "2020-07"
kent20_8 = pd.read_csv('/content/gdrive/My Drive/CE888 - Dataset/Kent 2018-20/2020-08-kent-stop-and-search.csv')
kent20_8["Date"] = "2020-08"
kent20_9 = pd.read_csv('/content/gdrive/My Drive/CE888 - Dataset/Kent 2018-20/2020-09-kent-stop-and-search.csv')
kent20_9["Date"] = "2020-09"
kent20_10 = pd.read_csv('/content/gdrive/My Drive/CE888 - Dataset/Kent 2018-20/2020-10-kent-stop-and-search.csv')
kent20_10["Date"] = "2020-10"
kent20_11 = pd.read_csv('/content/gdrive/My Drive/CE888 - Dataset/Kent 2018-20/2020-11-kent-stop-and-search.csv')
kent20_11["Date"] = "2020-11"
kent20_12 = pd.read_csv('/content/gdrive/My Drive/CE888 - Dataset/Kent 2018-20/2020-12-kent-stop-and-search.csv')
kent20_12["Date"] = "2020-12"
kent18 = pd.concat([kent18_1,kent18_2,kent18_3,kent18_4,kent18_5,kent18_6,kent18_7,kent18_8,kent18_9,kent18_10,kent18_11,kent18_12])
kent19 = pd.concat([kent19_1,kent19_2,kent19_3,kent19_4,kent19_5,kent19_6,kent19_7,kent19_8,kent19_9,kent19_10,kent19_11,kent19_12])
kent20 = pd.concat([kent20_1,kent20_2,kent20_3,kent20_4,kent20_5,kent20_6,kent20_7,kent20_8,kent20_9,kent20_10,kent20_11,kent20_12])
kent = pd.concat([kent18,kent19,kent20])

# %%
print (kent.shape)

#adding column for city
kent["City"] = "Kent"
kent.head()

#KENT DATA
# Out:
# (29562, 15)
#                         Type  ...  City
# 0  Person and Vehicle search  ...  Kent
# 1              Person search  ...  Kent
# 2  Person and Vehicle search  ...  Kent
# 3              Person search  ...  Kent
# 4  Person and Vehicle search  ...  Kent
#
# [5 rows x 16 columns]

# %%
#LONDON DATA

london18_1 = pd.read_csv('/content/gdrive/My Drive/CE888 - Dataset/London 2018-20/2018-01-city-of-london-stop-and-search.csv')
london18_1["Date"] = "2018-01"
london18_2 = pd.read_csv('/content/gdrive/My Drive/CE888 - Dataset/London 2018-20/2018-02-city-of-london-stop-and-search.csv')
london18_2["Date"] = "2018-02"
london18_3 = pd.read_csv('/content/gdrive/My Drive/CE888 - Dataset/London 2018-20/2018-03-city-of-london-stop-and-search.csv')
london18_3["Date"] = "2018-03"
london18_4 = pd.read_csv('/content/gdrive/My Drive/CE888 - Dataset/London 2018-20/2018-04-city-of-london-stop-and-search.csv')
london18_4["Date"] = "2018-04"
london18_5 = pd.read_csv('/content/gdrive/My Drive/CE888 - Dataset/London 2018-20/2018-05-city-of-london-stop-and-search.csv')
london18_5["Date"] = "2018-05"
london18_6 = pd.read_csv('/content/gdrive/My Drive/CE888 - Dataset/London 2018-20/2018-06-city-of-london-stop-and-search.csv')
london18_6["Date"] = "2018-06"
london18_7 = pd.read_csv('/content/gdrive/My Drive/CE888 - Dataset/London 2018-20/2018-07-city-of-london-stop-and-search.csv')
london18_7["Date"] = "2018-07"
london18_8 = pd.read_csv('/content/gdrive/My Drive/CE888 - Dataset/London 2018-20/2018-08-city-of-london-stop-and-search.csv')
london18_8["Date"] = "2018-08"
london18_9 = pd.read_csv('/content/gdrive/My Drive/CE888 - Dataset/London 2018-20/2018-09-city-of-london-stop-and-search.csv')
london18_9["Date"] = "2018-09"
london18_10 = pd.read_csv('/content/gdrive/My Drive/CE888 - Dataset/London 2018-20/2018-10-city-of-london-stop-and-search.csv')
london18_10["Date"] = "2018-10"
london18_11 = pd.read_csv('/content/gdrive/My Drive/CE888 - Dataset/London 2018-20/2018-11-city-of-london-stop-and-search.csv')
london18_11["Date"] = "2018-11"
london18_12 = pd.read_csv('/content/gdrive/My Drive/CE888 - Dataset/London 2018-20/2018-12-city-of-london-stop-and-search.csv')
london18_12["Date"] = "2018-12"
london19_1 = pd.read_csv('/content/gdrive/My Drive/CE888 - Dataset/London 2018-20/2019-01-city-of-london-stop-and-search.csv')
london19_1["Date"] = "2019-01"
london19_2 = pd.read_csv('/content/gdrive/My Drive/CE888 - Dataset/London 2018-20/2019-02-city-of-london-stop-and-search.csv')
london19_2["Date"] = "2019-02"
london19_3 = pd.read_csv('/content/gdrive/My Drive/CE888 - Dataset/London 2018-20/2019-03-city-of-london-stop-and-search.csv')
london19_3["Date"] = "2019-03"
london19_4 = pd.read_csv('/content/gdrive/My Drive/CE888 - Dataset/London 2018-20/2019-04-city-of-london-stop-and-search.csv')
london19_4["Date"] = "2019-04"
london19_5 = pd.read_csv('/content/gdrive/My Drive/CE888 - Dataset/London 2018-20/2019-05-city-of-london-stop-and-search.csv')
london19_5["Date"] = "2019-05"
london19_6 = pd.read_csv('/content/gdrive/My Drive/CE888 - Dataset/London 2018-20/2019-06-city-of-london-stop-and-search.csv')
lLondon19_6["Date"] = "2019-06"
london19_7 = pd.read_csv('/content/gdrive/My Drive/CE888 - Dataset/London 2018-20/2019-07-city-of-london-stop-and-search.csv')
london19_7["Date"] = "2019-07"
london19_8 = pd.read_csv('/content/gdrive/My Drive/CE888 - Dataset/London 2018-20/2019-08-city-of-london-stop-and-search.csv')
london19_8["Date"] = "2019-08"
london19_9 = pd.read_csv('/content/gdrive/My Drive/CE888 - Dataset/London 2018-20/2019-09-city-of-london-stop-and-search.csv')
london19_9["Date"] = "2019-09"
london19_10 = pd.read_csv('/content/gdrive/My Drive/CE888 - Dataset/London 2018-20/2019-10-city-of-london-stop-and-search.csv')
london19_10["Date"] = "2019-10"
london19_11 = pd.read_csv('/content/gdrive/My Drive/CE888 - Dataset/London 2018-20/2019-11-city-of-london-stop-and-search.csv')
london19_11["Date"] = "2019-11"
london19_12 = pd.read_csv('/content/gdrive/My Drive/CE888 - Dataset/London 2018-20/2019-12-city-of-london-stop-and-search.csv')
london19_12["Date"] = "2019-12"
london20_1 = pd.read_csv('/content/gdrive/My Drive/CE888 - Dataset/London 2018-20/2020-01-city-of-london-stop-and-search.csv')
london20_1["Date"] = "2020-01"
london20_2 = pd.read_csv('/content/gdrive/My Drive/CE888 - Dataset/London 2018-20/2020-02-city-of-london-stop-and-search.csv')
london20_2["Date"] = "2020-02"
london20_3 = pd.read_csv('/content/gdrive/My Drive/CE888 - Dataset/London 2018-20/2020-03-city-of-london-stop-and-search.csv')
london20_3["Date"] = "2020-03"
london20_4 = pd.read_csv('/content/gdrive/My Drive/CE888 - Dataset/London 2018-20/2020-04-city-of-london-stop-and-search.csv')
london20_4["Date"] = "2020-04"
london20_5 = pd.read_csv('/content/gdrive/My Drive/CE888 - Dataset/London 2018-20/2020-05-city-of-london-stop-and-search.csv')
london20_5["Date"] = "2020-05"
london20_6 = pd.read_csv('/content/gdrive/My Drive/CE888 - Dataset/London 2018-20/2020-06-city-of-london-stop-and-search.csv')
london20_6["Date"] = "2020-06"
london20_7 = pd.read_csv('/content/gdrive/My Drive/CE888 - Dataset/London 2018-20/2020-07-city-of-london-stop-and-search.csv')
london20_7["Date"] = "2020-07"
london20_8 = pd.read_csv('/content/gdrive/My Drive/CE888 - Dataset/London 2018-20/2020-08-city-of-london-stop-and-search.csv')
london20_8["Date"] = "2020-08"
london20_9 = pd.read_csv('/content/gdrive/My Drive/CE888 - Dataset/London 2018-20/2020-09-city-of-london-stop-and-search.csv')
london20_9["Date"] = "2020-09"
london20_10 = pd.read_csv('/content/gdrive/My Drive/CE888 - Dataset/London 2018-20/2020-10-city-of-london-stop-and-search.csv')
london20_10["Date"] = "2020-10"
london20_11 = pd.read_csv('/content/gdrive/My Drive/CE888 - Dataset/London 2018-20/2020-11-city-of-london-stop-and-search.csv')
london20_11["Date"] = "2020-11"
london20_12 = pd.read_csv('/content/gdrive/My Drive/CE888 - Dataset/London 2018-20/2020-12-city-of-london-stop-and-search.csv')
london20_12["Date"] = "2020-12"
london18 = pd.concat([london18_1,london18_2,london18_3,london18_4,london18_5,london18_6,london18_7,london18_8,london18_9,london18_10,london18_11,london18_12])
london19 = pd.concat([london19_1,london19_2,london19_3,london19_4,london19_5,london19_6,london19_7,london19_8,london19_9,london19_10,london19_11,london19_12])
london20 = pd.concat([london20_1,london20_2,london20_3,london20_4,london20_5,london20_6,london20_7,london20_8,london20_9,london20_10,london20_11,london20_12])
london = pd.concat([london18,london19,london20])
london["City"] = "London"
london.head()
